# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI


model = ChatOpenAI(
    model="qwen3:4b",
    api_key="ollama",
    base_url="http://localhost:11434/v1"
)

agent = create_agent(
    model=model,
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='8ab74256-2e78-4299-9e9c-0eef8c00d7c1'),
#               AIMessage(content='That\'s a fun question! 😊 But here\'s the important part: **I don’t have a favorite color** (I’m an AI, so I don’t have personal preferences or feelings 😄).  \n\nWhat *you* might be asking is: **"What is *your* favorite color?"**  \n(That’s probably what you meant — the "my" in your question is likely a small typo 😄).  \n\nSince I don’t know your personal preferences, **I’d love to hear what *your* favorite color is**!  \n\n👉 **Tell me what color you love most**, and I’ll:\n- Share why it’s special (e.g., "Blue makes people feel calm!" 🌊)\n- Give you fun facts about that color\n- Help you connect it to your personality or mood (e.g., "If you love oranges, you might be creative and energetic! 🍊")\n\n**P.S.** Favorite colors can change over time — and that’s totally okay! What color makes *you* feel happy right now? 💭 Just say it, and I’ll help you explore it!  \n\n*(P.P.S. If this was a typo, no worries — I’m here to help you figure it out!)* 🌟', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 796, 'prompt_tokens': 16, 'total_tokens': 812, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-760', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03899-f705-7de0-9c23-db7ccc932b4c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 796, 'total_tokens': 812, 'input_token_details': {}, 'output_token_details': {}})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime[ColourContext]) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime[ColourContext]) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model=model,
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='43983619-ac1b-47f9-89de-a7482beba3f0'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 309, 'prompt_tokens': 166, 'total_tokens': 475, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-896', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0389a-4469-76e3-9aed-220ec743d66e-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'call_e1at3g5u', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 166, 'output_tokens': 309, 'total_tokens': 475, 'input_token_details': {}, 'output_token_details': {}}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='95ca7291-1c57-4ef2-b992-65b1a40ad5b8', tool_call_id='call_e1at3g5u'),
#               AIMessage(content='Your favourite colour is blue.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 198, 'total_tokens': 285, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-657', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0389a-5276-7f21-ad16-87f8160e2aa7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 198, 'output_tokens': 87, 'total_tokens': 285, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='426806fe-ff9e-4d90-b750-b446878ac537'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 157, 'prompt_tokens': 166, 'total_tokens': 323, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-521', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0389a-56ec-7b61-98ab-8c909e5abac1-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'call_7h1qo53g', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 166, 'output_tokens': 157, 'total_tokens': 323, 'input_token_details': {}, 'output_token_details': {}}),
#               ToolMessage(content='green', name='get_favourite_colour', id='e24c5e97-5ded-4bd5-bfcb-abf83c9c2abd', tool_call_id='call_7h1qo53g'),
#               AIMessage(content='Your favourite colour is green.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 137, 'prompt_tokens': 198, 'total_tokens': 335, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-350', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0389a-7347-7202-9aeb-302166c39795-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 198, 'output_tokens': 137, 'total_tokens': 335, 'input_token_details': {}, 'output_token_details': {}})]}
