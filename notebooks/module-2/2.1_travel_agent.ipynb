# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

from langchain_openai import ChatOpenAI


model = ChatOpenAI(
    model="qwen3:4b",
    api_key="ollama",
    base_url="http://localhost:11434/v1"
)

agent = create_agent(
    model,
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='901add7c-8e99-4708-ba86-c9592a7096bb'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1722, 'prompt_tokens': 2615, 'total_tokens': 4337, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-945', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a03898-e44f-79d3-adc0-f26a5696ad37-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'SFO', 'flyTo': 'Tokyo', 'departureDate': '31/03/2024', 'adults': 1, 'max_sector_stopovers': 0}, 'id': 'call_d8rxwsbk', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2615, 'output_tokens': 1722, 'total_tokens': 4337, 'input_token_details': {}, 'output_token_details': {}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "SFO → Tokyo on 31/03/2024, 1 adult [≤0 stops/sector]",\n  "currency": null,\n  "passengers": null,\n  "resultsCount": 0,\n  "itineraries": [],\n  "searchTimeMs": 0,\n  "error": "These dates are in the past: departureDate (31/03/2024). Today is 25/08/2026 — please use dates today or later."\n}', 'id': 'lc_a8a29c7c-7549-4d96-b3dc-068dfbaa566b'}], name='search-flight', id='f8eac895-769e-46f6-8cb1-1bc47fb6cc59', tool_call_id='call_d8rxwsbk', artifact={'structured_content': {'query': 'SFO → Tokyo on 31/03/2024, 1 adult [≤0 stops/sector]', 'currency': None, 'passengers': None, 'resultsCount': 0, 'itineraries': [], 'searchTimeMs': 0, 'error': 'These dates are in the past: departureDate (31/03/2024). Today is 25/08/2026 — please use dates today or later.'}}),
#               AIMessage(content="I noticed that March 31, 2024 has already passed (today is August 25, 2026). Could you please check the date again? Let me know if you'd like to search for flights starting from today or a future date! 🌏", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 816, 'prompt_tokens': 2798, 'total_tokens': 3614, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-59', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03899-4364-7e92-8b68-9c701526b3ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2798, 'output_tokens': 816, 'total_tokens': 3614, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
print(response["messages"][-1].content)
# Out:
# I noticed that March 31, 2024 has already passed (today is August 25, 2026). Could you please check the date again? Let me know if you'd like to search for flights starting from today or a future date! 🌏
