# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain_openai import ChatOpenAI

# Ollama exposes an OpenAI-compatible API, so use ChatOpenAI with the local endpoint.
model = ChatOpenAI(
    model="qwen3:4b",
    openai_api_key="ollama",
    openai_api_base="http://localhost:11434/v1"
)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='That\'s a fun question with a **straightforward but important answer**—**there is no capital of the Moon**. Here\'s why, and a bit more context to make it clear:\n\n### 1️⃣ **The Moon isn\'t a country or political entity**  \n   - The Moon is a **natural satellite** of Earth (not a planet, country, or city).  \n   - It has **no government, no population**, and **no human settlements** (except temporary missions like Apollo).  \n   → **Therefore, there is no capital city**—just as there’s no capital for a mountain, a lake, or a star.\n\n### 2️⃣ **Why people might confuse this**  \n   - **Lunar features**: The Moon has named locations (e.g., *Maria* for "seas" of basalt, *Crater Copernicus*), but these are **not cities**.  \n   - **Future plans**: Organizations like NASA or the Lunar Gateway aim to build **temporary bases** (e.g., for scientific research), but these aren’t "capitals" and **don’t exist yet**.  \n   - **Fictional references**: In movies/sci-fi (e.g., *Moon* (2009) or *The Expanse*), lunar settlements might have "capitals," but this is **purely fictional**.\n\n### 3️⃣ **The closest "answers"** (for curiosity!)  \n   | **What it is**          | **Why it matters**                                                                 |\n   |--------------------------|---------------------------------------------------------------------------------|\n   | **Apollo 11 Landing Site** | Where humans first walked (Sea of Tranquility). *Not a capital*, but historically significant. |\n   | **Lunar South Pole**      | A target for future ice mining (potential future base), but still **no city**.     |\n   | **"Lunaria"** (fictional) | A sci-fi term for a lunar city—**not real**.                                     |\n\n### ✅ **The real answer**:  \n> **There is no capital of the Moon because the Moon doesn’t have a capital**.  \n\nIt’s a great question that highlights how we think about space—**the Moon is a place for exploration, not a human society**. If you meant a *fictional* lunar capital (like in games or movies), that’s entirely up to the creator! 😄\n\n*Fun fact*: The International Astronomical Union (IAU) officially names lunar features, but **no city exists**—so there’s no "capital" to debate! 🌕', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1012, 'prompt_tokens': 18, 'total_tokens': 1030, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-834', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02edd-4cf1-7f03-84ec-3d10ec17e6ab-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 1012, 'total_tokens': 1030, 'input_token_details': {}, 'output_token_details': {}})

# %%
print(response.content)
# Out:
# That's a fun question with a **straightforward but important answer**—**there is no capital of the Moon**. Here's why, and a bit more context to make it clear:
#
# ### 1️⃣ **The Moon isn't a country or political entity**
#    - The Moon is a **natural satellite** of Earth (not a planet, country, or city).
#    - It has **no government, no population**, and **no human settlements** (except temporary missions like Apollo).
#    → **Therefore, there is no capital city**—just as there’s no capital for a mountain, a lake, or a star.
#
# ### 2️⃣ **Why people might confuse this**
#    - **Lunar features**: The Moon has named locations (e.g., *Maria* for "seas" of basalt, *Crater Copernicus*), but these are **not cities**.
#    - **Future plans**: Organizations like NASA or the Lunar Gateway aim to build **temporary bases** (e.g., for scientific research), but these aren’t "capitals" and **don’t exist yet**.
#    - **Fictional references**: In movies/sci-fi (e.g., *Moon* (2009) or *The Expanse*), lunar settlements might have "capitals," but this is **purely fictional**.
#
# ### 3️⃣ **The closest "answers"** (for curiosity!)
#    | **What it is**          | **Why it matters**                                                                 |
#    |--------------------------|---------------------------------------------------------------------------------|
#    | **Apollo 11 Landing Site** | Where humans first walked (Sea of Tranquility). *Not a capital*, but historically significant. |
#    | **Lunar South Pole**      | A target for future ice mining (potential future base), but still **no city**.     |
#    | **"Lunaria"** (fictional) | A sci-fi term for a lunar city—**not real**.                                     |
#
# ### ✅ **The real answer**:
# > **There is no capital of the Moon because the Moon doesn’t have a capital**.
#
# It’s a great question that highlights how we think about space—**the Moon is a place for exploration, not a human society**. If you meant a *fictional* lunar capital (like in games or movies), that’s entirely up to the creator! 😄
#
# *Fun fact*: The International Astronomical Union (IAU) officially names lunar features, but **no city exists**—so there’s no "capital" to debate! 🌕

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-834',
#  'logprobs': None,
#  'model_name': 'qwen3:4b',
#  'model_provider': 'openai',
#  'system_fingerprint': 'fp_ollama',
#  'token_usage': {'completion_tokens': 1012,
#                  'completion_tokens_details': None,
#                  'prompt_tokens': 18,
#                  'prompt_tokens_details': None,
#                  'total_tokens': 1030}}

# %% [markdown]
# ## Customising your Model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="llama3:latest",
    model_provider="openai",
    base_url="http://localhost:11434/v1",
    api_key="ollama",
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# I'm happy to help! However, I must clarify that the Moon is a natural satellite and does not have a capital city. The Moon is a celestial body that is controlled by no country or government, and it does not have a established political system or governance structure. It's a celestial body that orbits the Earth!

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:2101, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    2100 try:
# -> 2101     data = self._create(payload)
#    2102 except anthropic.BadRequestError as e:
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1720, in ChatAnthropic._create(self, payload)
#    1719         return self._client.beta.messages.create(**payload)
# -> 1720     return self._client.messages.create(**payload)
#    1721 except TypeError as e:
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1049, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1048 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1049 return self._post(
#    1050     "/v1/messages",
#    1051     body=maybe_transform(
#    1052         {
#    1053             "max_tokens": max_tokens,
#    1054             "messages": messages,
#    1055             "model": model,
#    1056             "cache_control": cache_control,
#    1057             "container": container,
#    1058             "inference_geo": inference_geo,
#    1059             "metadata": metadata,
#    1060             "output_config": output_config,
#    1061             "service_tier": service_tier,
#    1062             "stop_sequences": stop_sequences,
#    1063             "stream": stream,
#    1064             "system": system,
#    1065             "temperature": temperature,
#    1066             "thinking": thinking,
#    1067             "tool_choice": tool_choice,
#    1068             "tools": tools,
#    1069             "top_k": top_k,
#    1070             "top_p": top_p,
#    1071         },
#    1072         message_create_params.MessageCreateParamsStreaming
#    1073         if stream
#    1074         else message_create_params.MessageCreateParamsNonStreaming,
#    1075     ),
#    1076     options=make_request_options(
#    1077         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1078     ),
#    1079     cast_to=Message,
#    1080     stream=stream or False,
#    1081     stream_cls=Stream[RawMessageStreamEvent],
#    1082 )
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1194, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192         response.read()
# -> 1194     raise self._make_status_error_from_response(response) from None
#    1196 raise RuntimeError("could not resolve response (should never happen)")
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}, 'request_id': 'req_011CeKnH5G8oW4Dy359ua6ph'}
#
# The above exception was the direct cause of the following exception:
#
# AnthropicAuthenticationError              Traceback (most recent call last)
# Cell In[7], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-6")
#       2
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:477, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     463 @override
#     464 def invoke(
#     465     self,
#    (...)    470     **kwargs: Any,
#     471 ) -> AIMessage:
#     472     config = ensure_config(config)
#     473     return cast(
#     474         "AIMessage",
#     475         cast(
#     476             "ChatGeneration",
# --> 477             self.generate_prompt(
#     478                 [self._convert_input(input)],
#     479                 stop=stop,
#     480                 callbacks=config.get("callbacks"),
#     481                 tags=config.get("tags"),
#     482                 metadata=config.get("metadata"),
#     483                 run_name=config.get("run_name"),
#     484                 run_id=config.pop("run_id", None),
#     485                 **kwargs,
#     486             ).generations[0][0],
#     487         ).message,
#     488     )
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1866, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1857 @override
#    1858 def generate_prompt(
#    1859     self,
#    (...)   1863     **kwargs: Any,
#    1864 ) -> LLMResult:
#    1865     prompt_messages = [p.to_messages() for p in prompts]
# -> 1866     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1673, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1670 for i, m in enumerate(input_messages):
#    1671     try:
#    1672         results.append(
# -> 1673             self._generate_with_cache(
#    1674                 m,
#    1675                 stop=stop,
#    1676                 run_manager=run_managers[i] if run_managers else None,
#    1677                 **kwargs,
#    1678             )
#    1679         )
#    1680     except BaseException as e:
#    1681         if run_managers:
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2009     result = generate_from_stream(iter(chunks))
#    2010 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2011     result = self._generate(
#    2012         messages, stop=stop, run_manager=run_manager, **kwargs
#    2013     )
#    2014 else:
#    2015     result = self._generate(messages, stop=stop, **kwargs)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:2105, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    2103     _handle_anthropic_bad_request(e)
#    2104 except anthropic.APIError as e:
# -> 2105     _handle_anthropic_api_error(e)
#    2106 return self._format_output(data, **kwargs)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:995, in _handle_anthropic_api_error(e)
#     993 """Re-raise an Anthropic SDK error as its LangChain-classified equivalent."""
#     994 if isinstance(e, anthropic.AuthenticationError):
# --> 995     raise AnthropicAuthenticationError(
#     996         message=e.message, response=e.response, body=e.body
#     997     ) from e
#     998 if isinstance(e, anthropic.PermissionDeniedError):
#     999     raise AnthropicPermissionDeniedError(
#    1000         message=e.message, response=e.response, body=e.body
#    1001     ) from e
#
# AnthropicAuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}, 'request_id': 'req_011CeKnH5G8oW4Dy359ua6ph'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model=model)

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='6488569b-af7c-48aa-985f-deaa0d326a9e'),
#               AIMessage(content='That\'s a fun question—but **the Moon does not have a capital** (or any capital at all), because:  \n\n1. **The Moon is not a country, city, or sovereign entity**. It’s Earth’s natural satellite with no population, government, or administrative structure.  \n2. **There are no permanent human settlements** on the Moon. While there are **temporary research sites** (like Apollo missions\' landing zones), they are not cities or capitals.  \n3. **No international agreement** designates a capital for the Moon, as it’s not part of any nation’s territory (the Moon is governed by the **Outer Space Treaty** of 1967, which prohibits national claims).  \n\n### Why this confusion might arise:\n- **Sci-fi inspiration**: Movies like *The Moon* (2023) or *Moon* (2009) sometimes feature fictional lunar cities with "capitals," but these are not real.  \n- **Misremembering**: You might be thinking of **Lunar Base Alpha** (a fictional base in *The Moon* movie) or real missions like **Artemis III** (planned for 2026), but these are temporary, crewed operations—not capitals.  \n- **Terminology mix-up**: The Moon has **no cities**, so it has **no capital city** (unlike countries, which have capitals).  \n\n### In short:  \n> ✅ **Answer: There is no capital of the Moon.**  \n> 💡 *The Moon has no human population, government, or cities—so it has no capital by definition.*  \n\nIf you meant something else (like a fictional setting or a different celestial body), let me know! 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 727, 'prompt_tokens': 18, 'total_tokens': 745, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-755', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02edf-7b7d-7531-b7d4-9cdd503c740d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 18, 'output_tokens': 727, 'total_tokens': 745, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question—but **the Moon does not have a capital** (or any capital at all), because:
#
# 1. **The Moon is not a country, city, or sovereign entity**. It’s Earth’s natural satellite with no population, government, or administrative structure.
# 2. **There are no permanent human settlements** on the Moon. While there are **temporary research sites** (like Apollo missions' landing zones), they are not cities or capitals.
# 3. **No international agreement** designates a capital for the Moon, as it’s not part of any nation’s territory (the Moon is governed by the **Outer Space Treaty** of 1967, which prohibits national claims).
#
# ### Why this confusion might arise:
# - **Sci-fi inspiration**: Movies like *The Moon* (2023) or *Moon* (2009) sometimes feature fictional lunar cities with "capitals," but these are not real.
# - **Misremembering**: You might be thinking of **Lunar Base Alpha** (a fictional base in *The Moon* movie) or real missions like **Artemis III** (planned for 2026), but these are temporary, crewed operations—not capitals.
# - **Terminology mix-up**: The Moon has **no cities**, so it has **no capital city** (unlike countries, which have capitals).
#
# ### In short:
# > ✅ **Answer: There is no capital of the Moon.**
# > 💡 *The Moon has no human population, government, or cities—so it has no capital by definition.*
#
# If you meant something else (like a fictional setting or a different celestial body), let me know! 😊

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='6fb4b6e9-e96d-41c5-84f9-5fc0e938c35b'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='85ad82b2-a675-45bf-b977-4dcc392cd85e', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='c6d85cb0-b355-4475-b3e7-295a1b31788f'),
#               AIMessage(content='Great question! But here\'s the important clarification first: **The Moon has no capital city, no government, and no permanent human population** (with the exception of a few short-term missions by astronauts). So **Luna City does not exist in reality**—it’s a **fictional concept** from sci-fi, games, or creative writing.  \n\nThat said, I’ll share why "Luna City" is such a cool idea *in fiction* and what real-world moon bases might look like:\n\n---\n\n### 🌕 Why "Luna City" Exists in Fiction (and What It Represents)\n1. **Sci-Fi Inspiration**:  \n   - The name "Luna" comes from Latin ("moon"), and in stories like *The Moon* (a 2016 novel series) or games like *Luna: A Journey to the Moon*, cities are imagined as lunar hubs.  \n   - In *The Expanse* universe, the Moon is called "the Moon" but isn’t a "city" — it’s more of a space station cluster.  \n   - **Fun fact**: NASA’s *Artemis program* aims to build a lunar base near the Moon’s south pole (not a city!), but it’s currently called **Artemis Base Camp** — a temporary research station.\n\n2. **Why Not a Real Capital?**  \n   - The Moon has **no governance**, so it can’t have a "capital." There are no cities, towns, or human settlements (only robotic probes and occasional astronauts).  \n   - If humans *did* build a permanent city on the Moon, it would likely be named something like:  \n     - **Olympus Base** (inspired by Olympus Mons on Mars)  \n     - **Luna One** (a placeholder for early lunar bases)  \n     - **Artemis City** (NASA’s future hub)\n\n3. **Real Moon "Cities" (for context)**:  \n   - **No cities** exist on the Moon. The closest thing to a "human presence" is:  \n     - **Lunar Crater Alpha** (a test site for NASA’s Artemis missions)  \n     - **The Lunar Gateway** (an orbiting space station around the Moon — *not* on the Moon itself).\n\n---\n\n### 🌟 A Playful "What If?" Scenario (For Fun!)\nIf Luna City *did* exist as a real capital, it might look like this:  \n| **Feature**          | **Real-World Inspiration**          | **Fictional Luna City**                |\n|-----------------------|-------------------------------------|----------------------------------------|\n| **Location**          | Lunar south pole (water ice)        | Tranquility Valley (calm, scenic)     |\n| **Purpose**           | Science base for water/robotics    | Home to moon farmers, scientists, and tourism |\n| **Architecture**      | Dome habitats (to handle vacuum)   | Glass-and-steel "lunar cities" with solar panels |\n| **Name**              | Artemis Base Camp                  | **Luna City** (for simplicity!)       |\n\n*Why "Luna City"?* It’s a catchy, easy-to-remember name that nods to the Moon’s Latin name while sounding like a real city (like "New York" → "Luna City").\n\n---\n\n### ✅ Summary for You:\n- ❌ **No real capital exists** on the Moon (it’s a natural satellite with no cities).  \n- ✅ **Luna City is fictional** (from sci-fi, games, or ideas).  \n- 🌍 **Real-world closest thing**: NASA’s **Artemis Base Camp** (a temporary research site, not a city).\n\nIf you enjoy this kind of fun space trivia, I’d love to know: **What would YOU name a real lunar capital?** 😊  \n*(Example answers: "Olympus Base," "Crescent City," "Lunar Haven")*', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1190, 'prompt_tokens': 45, 'total_tokens': 1235, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-924', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02edf-a93c-7a31-9a41-be00185fc3c9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 1190, 'total_tokens': 1235, 'input_token_details': {}, 'output_token_details': {}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# I'm afraid I need to correct you! There is no "Luna City" or any capital city on the Moon. The Moon is a natural satellite of Earth, and it does not have a city or any permanent human settlements. While there have been several lunar missions and temporary human settlements on the Moon, no city or capital has been established there.
#
# However, if you're interested in learning more about the Moon or hypothetical lunar colonization, I'd be happy to share some information!
#
# The Moon has been the subject of human fascination for centuries, and it remains a significant object of study and exploration in the fields of astronomy, geology, and space exploration. While we have sent numerous spacecraft to the Moon and even established a few short-term human settlements, no permanent city or capital has been established there.
#
# However, there have been plans and proposals for lunar colonization and even terraforming (altering the Moon's environment to make it habitable for humans) in the future. Some private companies and governments have even established lunar exploration and development programs, such as SpaceX's Starship program and NASA's Artemis program, which aim to return humans to the Moon and eventually establish a sustainable presence on the lunar surface.
#
# So while there may not be a "Luna City" or capital on the Moon yet, the possibility of human settlements and even cities on the Moon is an exciting and rapidly evolving area of research and exploration!
