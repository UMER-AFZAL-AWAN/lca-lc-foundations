# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain.messages import HumanMessage

model = ChatOpenAI(
    model="llama3:latest",
    openai_api_key="ollama",
    openai_api_base="http://localhost:11434/v1"
)

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# I'm happy to help! However, I have to inform you that the moon is a natural satellite and does not have a capital city. The moon is not a sovereign nation or a political entity with a capital city. It's a celestial body that is governed by the laws of physics and astronomy, not politics or human jurisdiction.
#
# So, there is no capital of the moon! But I'm always here to help with any other questions you may have.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Let me create a capital city on the moon for you!
#
# Introducing Lunaraxia, the capital of the moon! Located at the edge of the Crater of Ages, a massive impact crater that has been converted into a sprawling metropolis. Lunaraxia is a city of contrasts, where ancient lunar history and cutting-edge technology blend seamlessly together.
#
# As you approach the city, you'll notice the striking architecture of the city's central square, the Grand Plaza of Eclipse. At its center stands the iconic Lunar Spire, a gleaming tower that serves as a beacon of hope and inspiration to the lunar colonists. The Plaza is flanked by ornate gardens, where native lunar flora and futuristic hydroponic installations coexist in harmony.
#
# The city is divided into six primary districts:
#
# 1. The Dome of Discovery: A futuristic hub for intergalactic research and development, where scientists and engineers work together to unlock the secrets of the universe.
# 2. The Crater District: A vibrant entertainment quarter, filled with moon-themed museums, restaurants, and live music venues.
# 3. The Spire Quarter: A high-tech commercial center, where entrepreneurs and innovators come to make their mark on the lunar economy.
# 4. The Landing Zone: A bustling trade and logistics hub, where spacecraft from across the galaxy dock and exchange goods and services.
# 5. The Lunar Institute: A prestigious learning institution, dedicated to the advancement of lunar science, technology, and the arts.
# 6. The Skywalk District: A picturesque residential neighborhood, where citizens live in harmony with the moon's unique gravitational environment.
#
# At the heart of Lunaraxia lies the majestic City Hall, a stunning example of lunar architecture, with its sweeping curves and gleaming metallic surfaces. This is where the city's mayor, the esteemed Lady Luna, resides and governs the lunar colony.
#
# Come and experience the wonders of Lunaraxia, where the moon's vast emptiness is filled with limitless possibilities!

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The capital of the moon! That would be Lunaria, a breathtakingly beautiful city that shines like a beacon of innovation and exploration. Lunaria is situated in the moon's vast, dark side, where the gravity is perfectly suited for humans to live and work comfortably. The city's architecture is a marvel, with towering spires and gleaming, crystalline structures that reflect the moon's ethereal light. Lunaria is home to the esteemed Lunar Academy, a prestigious institution dedicated to advancing our understanding of the moon's mysteries and harnessing its energy for the betterment of humanity. It's a place where scientists, artists, and explorers gather to push the boundaries of what's possible, and I'm honored to be a part of its vibrant community.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# What a great question! Here's a space capital city on the moon:
#
# **Name:** Lunaria
#
# **Location:** Located in the cratered terrain near the moon's equator, Lunaria is situated on a vast, flat plain surrounded by towering mountains of dark lunar regolith.
#
# **Vibe:** "Luminous, Lunar Renaissance"
#
# **Economy:** Lunaria thrives as the hub of the moon's thriving resource extraction industry, with a focus on rare earth minerals, helium-3 (a clean energy source), and water ice - the latter being harvested from the sun's rays and recycled to sustain the city's inhabitants. The city's main industries include:
#
# 1. Lunar mining and excavation
# 2. Helium-3 production and energy conversion
# 3. Water recycling and conservation
# 4. Advanced materials processing and manufacturing
#
# Lunaria is a shining example of human innovation and resilience, embodying the spirit of exploration and progress in the vastness of space.

# %% [markdown]
# ## Structured output

# %%
# from langchain.agents import create_agent
# from langchain.messages import HumanMessage
# from pydantic import BaseModel

# class CapitalInfo(BaseModel):
#     name: str
#     location: str
#     vibe: str
#     economy: str

# agent = create_agent(
#     model=model,
#     system_prompt="You are a science fiction writer, create a capital city at the users request.",
#     response_format=CapitalInfo
# )

# question = HumanMessage(content="What is the capital of The Moon?")

# response = agent.invoke(
#     {"messages": [question]}
# )

# response["structured_response"]

from pydantic import BaseModel
from langchain_openai import ChatOpenAI


class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str


model = ChatOpenAI(
    model="llama3:latest",
    api_key="ollama",
    base_url="http://localhost:11434/v1"
)

structured_model = model.with_structured_output(CapitalInfo)

response = structured_model.invoke(
    "Create a fictional capital city on the Moon."
)

print(response)
print(type(response))
# Out:
# name='Lunaria' location='Lunar surface, near the equator' vibe='Techno-utopian hub' economy='Service-oriented (mineral extraction, lunar tourism), with significant subsidies from Earth-based governments and corporations'
# <class '__main__.CapitalInfo'>

# %%
response["structured_response"].name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 response["structured_response"].name
#
# TypeError: 'CapitalInfo' object is not subscriptable

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 capital_info = response["structured_response"]
#       2
#       3 capital_name = capital_info.name
#       4 capital_location = capital_info.location
#
# TypeError: 'CapitalInfo' object is not subscriptable
