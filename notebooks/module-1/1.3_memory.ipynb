# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI


model = ChatOpenAI(
    model="qwen3:4b",
    api_key="ollama",
    base_url="http://localhost:11434/v1"
)

agent = create_agent(
    model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='18059f5d-46ee-46ad-a86d-92fa929992a6'),
#               AIMessage(content='Hello Seán! 👋 It’s great to meet you—I love that you mentioned your favorite color is green. (As an Irish name, that’s a perfect match too! 🌿)  \n\nHow can I help you today? Whether it’s answering questions, brainstorming ideas, or just chatting—I’m here to make it fun and easy for you. 😊  \n\n*(P.S. If you’re Irish, you might appreciate this tiny fact: In Ireland, green is the *national color*—it’s tied to history, nature, and even the legendary *Táin Bó Cúailnge* epic! But don’t worry if you didn’t know—I just had to share.)*  \n\nLet me know how I can assist! 🌱', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 422, 'prompt_tokens': 22, 'total_tokens': 444, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-102', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02e2d-f0e3-78c3-820c-cee39c6423ef-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 422, 'total_tokens': 444, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='eab6e263-f107-4ecb-aadb-1b237368c33d'),
#               AIMessage(content='That\'s a great question—but I need to be honest: **I don’t have personal favorites** 😊 I’m an AI, so I don’t have feelings, preferences, or senses like humans do! I can’t *choose* a favorite color, but I **can help you figure out what *your* favorite color might be** (or why you love a particular one). \n\n### What I *can* do for you:\n✅ **Tell you about color psychology** (e.g., why blue feels calm, red energizes us, etc.)  \n✅ **Help you pick a color** for an assignment, art, or even styling!  \n✅ **Answer questions** like *"Why do I love blue?"* or *"What color matches my personality?"*  \n\nSo—**what’s *your* favorite color?** 🌈  \n*(Just tell me, and I’ll help you explore it!)*  \n\n*P.S. If you’re asking this because you’re curious about color meanings, I’d love to dive into that too!* 😄', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 625, 'prompt_tokens': 16, 'total_tokens': 641, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-931', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02e2e-37bf-7e41-8cdf-748f5e09ddfc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 625, 'total_tokens': 641, 'input_token_details': {}, 'output_token_details': {}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='21297bff-27ff-4fc4-ba69-6ea52d866ab8'),
#               AIMessage(content="Hello Seán! 😊 That's a lovely name—and green is such a wonderful favorite color (it’s the color of hope, growth, and nature, which is perfect!). I love that you picked it—green is one of my top choices too!  \n\nHow did green become your favorite? Is there a special reason (like nature, Irish heritage, or something else)? I’d love to hear your story! 🌿  \n\nEither way—keep shining in your green! ✨", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 438, 'prompt_tokens': 22, 'total_tokens': 460, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-238', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02e2e-c590-7090-958a-b37eb6bfb364-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 438, 'total_tokens': 460, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='21297bff-27ff-4fc4-ba69-6ea52d866ab8'),
#               AIMessage(content="Hello Seán! 😊 That's a lovely name—and green is such a wonderful favorite color (it’s the color of hope, growth, and nature, which is perfect!). I love that you picked it—green is one of my top choices too!  \n\nHow did green become your favorite? Is there a special reason (like nature, Irish heritage, or something else)? I’d love to hear your story! 🌿  \n\nEither way—keep shining in your green! ✨", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 438, 'prompt_tokens': 22, 'total_tokens': 460, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-238', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02e2e-c590-7090-958a-b37eb6bfb364-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 438, 'total_tokens': 460, 'input_token_details': {}, 'output_token_details': {}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='e2a0b0d0-6b38-468d-8639-faea9d59b9c4'),
#               AIMessage(content='Ah, Seán! 👋 You already told me your favorite color is **green** — and I *love* that you picked it (it’s my favorite too!). 🌿  \n\nSo to be clear: **your favorite color is green** ✅  \n(You even mentioned it yourself earlier — *that’s* why it’s special!)  \n\nBut since you’re asking again, I’m guessing you might be wondering:  \n👉 *“Is this the right answer for me?”*  \n👉 *“Why does green feel so right to me?”*  \n\nIf you’d like, I’d love to hear **what makes green special to you** — whether it’s the color of your Irish roots, the forest you love, or just the way it makes you feel. *(I’m all ears!)* 🌱  \n\nJust say the word — I’m here for your green story. 💚', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 689, 'prompt_tokens': 137, 'total_tokens': 826, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-27', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02e2e-d941-7691-8f95-33dca636c626-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 137, 'output_tokens': 689, 'total_tokens': 826, 'input_token_details': {}, 'output_token_details': {}})]}
