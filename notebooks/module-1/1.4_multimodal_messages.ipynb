# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI


model = ChatOpenAI(
    model="qwen2.5vl:3b",
    api_key="ollama",
    base_url="http://localhost:11434/v1"
)

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# As a science fiction writer, I can definitely provide you with an imaginative capital for your Moon city!
#
# Let's call it **Luna Regia**. Named after the Latin word for "City of the Moon," Luna Regia embodies the themes of exploration, future technology, and international collaboration in the face of our expanding universe.
#
# ### Luna Regia: The Capital of the Moon
#
# **Location and Geography:**
# Luna Regia is situated on the southern hemisphere of the Moon, in the region known as the Mare Imbrium. The city is set upon a series of towering white sand dunes, with mountains of white rock spilling into a great river where water is abundant but pure, free-flowing from a central fountain. The sky is filled with the silvery glow of a nearby sun, and a massive array of satellite dishes dot the landscape, each communicating across vast distances.
#
# **Architecture and Infrastructure:**
# The city is divided into sectors that reflect the various functions required on the Moon:
#
# 1. **Housing and Research Sector:** A sprawling network of high-rise residential towers, each a microcosm of Earth’s urban architecture, topped by viewing platforms offering unparalleled lunar views. The buildings are a canvas of Earthly themes, but with an earthy, alien twist—materials reflect the colors of the moon’s cratered surface.
#
# 2. **Commercial District:** The heart of Luna Regia is buzzing with activity. High-rise commercial buildings house both local businesses and international offices. The streets are filled with gleaming spaceships, landing pads for lunar and inter-planetary tourism, and bustling restaurants and bars where the best of lunar food is served, combined with a wide array of interplanetary drinks.
#
# 3. **Trade and Industry Sector:** Here, factories, processing plants, and mining equipment coexist. The industry sector is surrounded by vast fields of lunar plantations, experimenting with growing plants from Earth in lunar soil.
#
# 4. **Art and Entertainment District:** This is the heart of artistry and creativity, with studios and galleries showcasing unique lunar art forms and performances by interplanetary performers. The district hosts music festivals and arts conventions, bringing together the vibrant worlds of music, crafts, and visual art.
#
# 5. **Science and Research Labs:** The scientific sector houses extensive lunar exploration facilities and laboratories where astronauts and researchers conduct studies on microgravity effects, plant growth under lunar conditions, and other experiments crucial for future colonization of the Moon.
#
# 6. **Astronomy Hub:** Luna Regia is a key research center for space archaeology and lunar paleontology, with telescopes large enough to see stars not visible from Earth. Various astronomical telescopes and observation sites are spread across the city for cosmic exploration.
#
# 7. **Government and Administration Center:** The government sector is the nucleus of lunar governance, a sprawling central building complex complete with holographic chambers for meetings and a large auditorium for public forums. The administration center manages interplanetary trade agreements and international relations.
#
# ### Cultural and Social Elements:
# In Luna Regia, cultural diversity is as important as economic prosperity. Lunar festivals celebrate, music that blends terrestrial and lunar notes, and traditions that are unique to the city. There are lunar poetry competitions, artistic competitions, and even interplanetary dance festivals where artists from different planets compete for the title "Moon Dancer of the Year."
#
# ### Environment and Sustainability:
# Given the finite resources of the Moon, Luna Regia focuses heavily on efficient use of resources. Water reclamation systems and recycling programs are state-of-the-art. The city is also an advocate for biodiversity, with various artificial ecosystems created for species that cannot survive on the lunar surface.
#
# ### Conclusion:
# Luna Regia is not just a place—it's a vibrant community of science, technology, and international collaboration. It's a place where the wonders of our universe are explored, new technologies are developed, and the human spirit strives for understanding and unity across the vastness of space.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'images.png', 'type': 'image/png', 'size': 20957, 'content': <memory at 0x000002958C29EB00>, 'last_modified': datetime.datetime(2026, 8, 23, 12, 12, 16, 547000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# This image depicts the inside of a modern, fully stocked refrigerator. The refrigerator is tall and narrow, with a sleek stainless steel finish that exudes elegance and sophistication. The door is open, revealing an organized interior with multiple shelves and bins.
#
# Each shelf is stocked with a variety of both perishable and non-perishable items, demonstrating a well-managed inventory. Toward the bottom right and middle right sections, there are bins specifically for storage, which can be removed or adjusted to fit the user's specific needs.
#
# The door displays items in bins, where one bin contains vegetables and the other contains fruits. There are different jars and containers holding items on the top tier, with some labeled, and others lined with small dividers for organization.
#
# The middle section shows bottles, including some with black caps and others with green caps, alongside jars and containers for storage. The top left and center areas are filled with smaller jars and containers of various sizes, neatly arranged and organized.
#
# On the top right, there’s a set of three bottles; two of them are full, and one appears to be empty. To the far right, there's a small bin, filled with a jar of what seems to be some type of condiment or sauce that’s partially open, with a slight greenish hue.
#
# All items are clearly tagged, suggesting a well-maintained and tidy home. This image illustrates a sense of organization and efficient use of space, enhancing food safety and making it easier to find and access items. There are no visible tags or digital display controls visible, indicating a focus on simplicity and modern aesthetics.
#
# This refrigerator's design and organization offer a practical solution not only for storage and cooking but also for serving as a kitchen or dining area in itself, showcasing a blend of functionality and design.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 6
#       2 from scipy.io.wavfile import write
#       3 import base64
#       4 import io
#       5 import time
# ----> 6 from tqdm import tqdm
#       7
#       8 # Recording settings
#       9 duration = 5  # seconds
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
