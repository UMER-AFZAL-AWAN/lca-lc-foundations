# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="qwen3",
    api_key="ollama",
    base_url="http://localhost:11434/v1"
)


agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 500?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 500 is approximately **22.3607** (rounded to four decimal places).

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 500?', additional_kwargs={}, response_metadata={}, id='cf991d71-8f1f-42a7-b69b-1a47982aee1a'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 213, 'prompt_tokens': 162, 'total_tokens': 375, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-389', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a02e04-be80-7ed0-a421-12f13a2e8e1a-0', tool_calls=[{'name': 'square_root', 'args': {'x': 500}, 'id': 'call_35p12pqr', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 162, 'output_tokens': 213, 'total_tokens': 375, 'input_token_details': {}, 'output_token_details': {}}),
#  ToolMessage(content='22.360679774997898', name='square_root', id='7bae45e9-6d96-4e38-9683-8c1e6e7610c3', tool_call_id='call_35p12pqr'),
#  AIMessage(content='The square root of 500 is approximately **22.3607** (rounded to four decimal places).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1339, 'prompt_tokens': 214, 'total_tokens': 1553, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3:4b', 'system_fingerprint': 'fp_ollama', 'id': 'chatcmpl-268', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a02e04-c861-7e22-9fef-6ae9348b4573-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 214, 'output_tokens': 1339, 'total_tokens': 1553, 'input_token_details': {}, 'output_token_details': {}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 500}, 'id': 'call_35p12pqr', 'type': 'tool_call'}]
