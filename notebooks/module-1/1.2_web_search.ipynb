# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI


model = ChatOpenAI(
    model="qwen3:4b",
    api_key="ollama",
    base_url="http://localhost:11434/v1"
)


agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# 我的训练数据截止时间是2024年10月，这意味着我的知识更新到2024年10月。如果您有具体问题，我会尽力根据现有知识回答，但请注意，我不具备实时数据获取能力。

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# ---------------------------------------------------------------------------
# InvalidAPIKeyError                        Traceback (most recent call last)
# Cell In[5], line 14
#      10     """Search the web for information"""
#      11
#      12     return tavily_client.search(query)
#      13
# ---> 14 web_search.invoke("Who is the current mayor of San Francisco?")
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\tools\base.py:764, in BaseTool.invoke(self, input, config, **kwargs)
#     756 @override
#     757 def invoke(
#     758     self,
#    (...)    761     **kwargs: Any,
#     762 ) -> Any:
#     763     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 764     return self.run(tool_input, **kwargs)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\tools\base.py:1132, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1130 if error_to_raise:
#    1131     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1132     raise error_to_raise
#    1133 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1134 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\tools\base.py:1098, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1096     if config_param := _get_runnable_config_param(self._run):
#    1097         tool_kwargs |= {config_param: config}
# -> 1098     response = context.run(self._run, *tool_args, **tool_kwargs)
#    1099 if self.response_format == "content_and_artifact":
#    1100     msg = (
#    1101         "Since response_format='content_and_artifact' "
#    1102         "a two-tuple of the message content and raw tool output is "
#    1103         f"expected. Instead, generated response is of type: "
#    1104         f"{type(response)}."
#    1105     )
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\tools\structured.py:97, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      95     if config_param := _get_runnable_config_param(self.func):
#      96         kwargs[config_param] = config
# ---> 97     return self.func(*args, **kwargs)
#      98 msg = "StructuredTool does not support sync invocation."
#      99 raise NotImplementedError(msg)
#
# Cell In[5], line 12, in web_search(query)
#       8 def web_search(query: str) -> Dict[str, Any]:
#       9
#      10     """Search the web for information"""
#      11
# ---> 12     return tavily_client.search(query)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\tavily\client.py:117, in TavilyClient.search(self, query, search_depth, max_results, include_domains, exclude_domains, include_answer, include_raw_content, **kwargs)
#     115     else:
#     116         self._update_usage_stats(success=False)
# --> 117         self._handle_error(response)
#     119 except requests.exceptions.Timeout:
#     120     self._update_usage_stats(success=False)
#
# File C:\D\Codes\LangChain\lca-lc-foundations\.venv\Lib\site-packages\tavily\client.py:302, in TavilyClient._handle_error(self, response)
#     299     error_msg = response.text
#     301 if response.status_code == 401:
# --> 302     raise InvalidAPIKeyError(f"Invalid API key: {error_msg}")
#     303 elif response.status_code == 429:
#     304     raise UsageLimitExceededError(f"Usage limit exceeded: {error_msg}")
#
# InvalidAPIKeyError: Invalid API key: Unauthorized: missing or invalid API key.

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
